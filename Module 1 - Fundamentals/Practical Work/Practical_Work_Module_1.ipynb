# %% [markdown]
# # **Practical Work - Module 1**
#
# This Practical Work in Module 1 has the objective to use **Google Colab**, **Power BI** and **K-Means Algorithms** as tools for the data processing and visualization.
#
# As part of the course evaluation process, they will be used to answer some questions.

# %% [markdown]
# ### **Part 1: Using Google Colab and K-Means Algorithms**
#
# Considering a dataset generated by the code:
# *make_blobs(n_samples=500, centers=20, random_state=999)*, execute K-Means algorithm with these parameters:
#
#
# *   init = k-means++
# *   max_iter = 300
# *   n-init = 10

# %%
# Importing libraries
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
# Generating the dataset
X, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# #### **Question 4: Using the dataset above, if K-Means are executed for just 1 cluster, what will be the centroid coordinates at the end of execution?**

# %%
# Using only 1 cluster for the dataset
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10)
pred_y = kmeans.fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=pred_y)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=70, c='blue')
plt.show()

# %% [markdown]
# ###### **Answer: [ 0.02618523 -1.30384304]**

# %% [markdown]
# #### **Question 5: Using the dataset above, if K-Means are executed for just 1 cluster, what will be the value of WCSS *(Within Cluster Sum of Squares)* at the end of execution?**

# %%
# Setting only 1 cluster for the dataset
kmeans = KMeans(n_clusters=1, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
print(kmeans.inertia_)
# Out:
# 31547.372471390485

# %% [markdown]
# #### **Answer: 31547.372471390485**

# %% [markdown]
# #### **Question 6: Using the dataset above, if K-Means are executed for just 5 clusters, what will be the value of WCSS *(Within Cluster Sum of Squares)* at the end of execution?**

# %%
# Setting 5 clusters for the dataset
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10)
kmeans.fit(X)
print(kmeans.inertia_)
# Out:
# 4717.404091931214

# %% [markdown]
# #### **Answer: 4717.404091931214**

# %% [markdown]
# #### **Question 7: Using the dataset above, what will be the ideal number of clusters?**

# %%
# This function is used to calculate the better number of cluster on the dataset
def optimal_number_of_clusters(wcss):
    x1, y1 = 1, wcss[0]
    x2, y2 = 19, wcss[len(wcss)-1]
    distances = []
    for i in range(len(wcss)):
        x0 = i + 1
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)

    
    return distances.index(max(distances)) + 1

# %%
# This piece of code will criate a range of clusters and, using Elbow Method, is possible to identify on the chart the ideal number of clusters.
# Looking at the chart: the ideal number of clusters is located at the most distant point of the cluster line (in blue), drawing a line perpendicular to the straight line (in orange).
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    print('Clusters:', i, '    WCSS:', wcss[i-1])

plt.plot(range(1, 20), wcss)
plt.plot([1, 19],[wcss[0], wcss[len(wcss)-1]])
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()
# Out:
# Clusters: 1     WCSS: 31547.372471390485
# Clusters: 2     WCSS: 16949.214472147927
# Clusters: 3     WCSS: 9464.847250570496
# Clusters: 4     WCSS: 6005.101775346179
# Clusters: 5     WCSS: 4717.404091931214
# Clusters: 6     WCSS: 3662.6403286096665
# Clusters: 7     WCSS: 2980.5708362003215
# Clusters: 8     WCSS: 2490.7371368023755
# Clusters: 9     WCSS: 2050.2071307551255
# Clusters: 10     WCSS: 1842.8811515681252
# Clusters: 11     WCSS: 1648.1075997416451
# Clusters: 12     WCSS: 1474.7594817414426
# Clusters: 13     WCSS: 1332.759102856693
# Clusters: 14     WCSS: 1161.2708876955853
# Clusters: 15     WCSS: 1059.6653573957274
# Clusters: 16     WCSS: 995.3390925920576
# Clusters: 17     WCSS: 908.7283086446021
# Clusters: 18     WCSS: 841.329451692872
# Clusters: 19     WCSS: 793.3122809796835

# %%
# This code will determine the ideal number of clusters
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
n = optimal_number_of_clusters(wcss)
print('Ideal number of clusters: ', n)
# Out:
# Ideal number of clusters:  4

# %% [markdown]
# #### **Answer: 4 clusters**

# %% [markdown]
# ### **Part 2: Novel Corona Virus 2019 Dataset**
#
# We are using the dataset about the Corona Virus 2019 available at
# https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset?select=covid_19_data.csv

# %% [markdown]
# #### **Question 8: Using the Power BI and the Corona Virus dataset above, create a chart using "Confirmed", "Deaths", "Recovered", and "Active' for China. How it will be the chart?**
#
# ##### **Answer:**
#
# ![Chart - Question 8 China.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Question 9: Using the Power BI and the Corona Virus dataset above, select Italy, and answer: in which month did the country have more cases Recovered than Active cases?**
#
# ![Chart - Question 9 Italy.jpg](data:image/jpeg;base64,...)
# ##### **Answer: May**

# %% [markdown]
# #### **Question 10: Using the Power BI and the Corona Virus dataset above, select South Corea, and answer: in which month did the country reach the peak of Active cases?**
#
# ![Chart - Question 10 South Corea.jpg](data:image/jpeg;base64,...)
# ##### **Answer: March**

# %% [markdown]
# #### **Question 11: Using the Power BI and the Corona Virus dataset above, select Italy and create a chart only with the Active values. How it will be the chart?**
#
# ##### **Answer:**
# ![Chart - Question 11 Italy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Question 12: Using the Power BI and the Corona Virus dataset above, select Venezuela, and answer: in which month did the country for the first time recover more cases than active cases?**
#
# ![Chart - Question 12 Venezuela.jpg](data:image/jpeg;base64,...)
#
# ##### **Answer: April**
